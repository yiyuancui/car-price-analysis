# %%
import pandas as pd

# %% [markdown]
# # Clean up the data and form new dataset

# %%
df = pd.read_csv('car_prices.csv', low_memory = False)

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca         5   16639.0  white    black
# 1  5xyktca69fg561319    ca         5    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       4.5    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       4.1   14282.0  white    black
# 4  wba6b2c57ed129731    ca       4.3    2641.0   gray    black
#
#                                    seller    mmr  sellingprice  \
# 0                 kia motors america, inc  20500         21500
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# year
# make
# model
# trim
# body
# transmission
# vin
# state
# condition
# odometer
# color
# interior
# seller
# mmr
# sellingprice
# saledate
# Unnamed: 16

# %%
new_df = df[["year", "make",'model','trim','body','transmission','state','condition','odometer','color','interior','sellingprice','saledate']]

# %%
new_df.to_csv('cleaned_car_price.csv')

# %%
model = 'Sorento'
model_df = df.loc[df['model'] == make]
year_model_df = model_df.loc[make_df['year'] == 2015]
year_model_df['sellingprice'].mean()
# Out:
# 20339.476495726496

# %%
model = '3 Series'
model_df = df.loc[df['model'] == make]
year_model_df = model_df.loc[make_df['year'] == 2015]
year_model_state_df = year_model_df.loc[year_model_df['state'] == 'ca']
year_model_state_df['sellingprice'].mean()
# Out:
# 21225.694444444445

# %%
new_df['odometer'].max()
# Out:
# 999999.0

# %% [markdown]
# # plot relationship between some specific car versus every year, and do a prediction on the next 3 year's price

# %%
df = pd.read_csv('cleaned_car_price.csv', low_memory = False)

# %% [markdown]
# # change sale date to years

# %%
df.head()
# Out:
#    Unnamed: 0  year   make                model        trim   body  \
# 0           0  2015    Kia              Sorento          LX    SUV
# 1           1  2015    Kia              Sorento          LX    SUV
# 2           2  2014    BMW             3 Series  328i SULEV  Sedan
# 3           3  2015  Volvo                  S60          T5  Sedan
# 4           4  2014    BMW  6 Series Gran Coupe        650i  Sedan
#
#   transmission state condition  odometer  color interior  sellingprice  \
# 0    automatic    ca         5   16639.0  white    black         21500
# 1    automatic    ca         5    9393.0  white    beige         21500
# 2    automatic    ca       4.5    1331.0   gray    black         30000
# 3    automatic    ca       4.1   14282.0  white    black         27750
# 4    automatic    ca       4.3    2641.0   gray    black         67000
#
#                                   saledate
# 0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# 1  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)
# ...

# %%
x = list(df['saledate'].str.strip())
print(type(x))
# Out:
# <class 'list'>

# %%
for i in range(len(x)):
    x[i] = x[i][11:15]
print(x[:100])
# Out:
# ['2014', '2014', '2015', '2015', '2014', '2014', '2014', '2014', '2014', '2015', '2014', '2014', '2015', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2015', '2015', '2014', '2014', '2015', '2014', '2015', '2015', '2014', '2014', '2014', '2015', '2014', '2014', '2014', '2015', '2014', '2015', '2015', '2015', '2015', '2014', '2015', '2014', '2014', '2014', '2014', '2015', '2014', '2014', '2014', '2014', '2014', '2014', '2015', '2014', '2015', '2014', '2014', '2014', '2015', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2015', '2015', '2014', '2014', '2014', '2014', '2015', '2014', '2015', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2015', '2014', '2014', '2014', '2015', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014', '2014']

# %%
print(len(x))
# Out:
# 558837

# %%
df['saledate'] = x

# %%
df
# Out:
#         Unnamed: 0  year    make                model         trim       body  \
# 0                0  2015     Kia              Sorento           LX        SUV
# 1                1  2015     Kia              Sorento           LX        SUV
# 2                2  2014     BMW             3 Series   328i SULEV      Sedan
# 3                3  2015   Volvo                  S60           T5      Sedan
# 4                4  2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...            ...   ...     ...                  ...          ...        ...
# 558832      558832  2015     Kia                 K900       Luxury      Sedan
# 558833      558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834      558834  2012     BMW                   X5    xDrive35d        SUV
# 558835      558835  2015  Nissan               Altima        2.5 S      sedan
# 558836      558836  2014    Ford                F-150          XLT  SuperCrew
#
# ...

# %%
df = df.rename(columns={'saledate': 'saleyear'})

# %%
df
# Out:
#         Unnamed: 0  year    make                model         trim       body  \
# 0                0  2015     Kia              Sorento           LX        SUV
# 1                1  2015     Kia              Sorento           LX        SUV
# 2                2  2014     BMW             3 Series   328i SULEV      Sedan
# 3                3  2015   Volvo                  S60           T5      Sedan
# 4                4  2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...            ...   ...     ...                  ...          ...        ...
# 558832      558832  2015     Kia                 K900       Luxury      Sedan
# 558833      558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834      558834  2012     BMW                   X5    xDrive35d        SUV
# 558835      558835  2015  Nissan               Altima        2.5 S      sedan
# 558836      558836  2014    Ford                F-150          XLT  SuperCrew
#
# ...

# %%
# save new csv

# %%
df.to_csv('clean_car_price.csv', index = False)

# %%
df = pd.read_csv('clean_car_price.csv', low_memory = False)
df.head()
# Out:
#    Unnamed: 0  year   make                model        trim   body  \
# 0           0  2015    Kia              Sorento          LX    SUV
# 1           1  2015    Kia              Sorento          LX    SUV
# 2           2  2014    BMW             3 Series  328i SULEV  Sedan
# 3           3  2015  Volvo                  S60          T5  Sedan
# 4           4  2014    BMW  6 Series Gran Coupe        650i  Sedan
#
#   transmission state condition  odometer  color interior  sellingprice  \
# 0    automatic    ca         5   16639.0  white    black         21500
# 1    automatic    ca         5    9393.0  white    beige         21500
# 2    automatic    ca       4.5    1331.0   gray    black         30000
# 3    automatic    ca       4.1   14282.0  white    black         27750
# 4    automatic    ca       4.3    2641.0   gray    black         67000
#
#    saleyear
# 0    2014.0
# 1    2014.0
# 2    2015.0
# 3    2015.0
# 4    2014.0

# %%
# change car year - 1 to get actual car year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 df.drop('Unnamed: 0.1')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
# ...
